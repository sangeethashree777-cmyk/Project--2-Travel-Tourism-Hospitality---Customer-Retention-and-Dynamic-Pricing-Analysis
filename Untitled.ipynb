# %%
import pandas as pd

# %%
import numpy as py

# %%
df= pd.read_csv(r"C:\Users\Harish\Downloads\Project -2 Travel-Tourism-Hospitality---Customer-Retention-and-Dynamic-Pricing-Analysis\Travel_Tourism_Hospitality_Uncleaned_Dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3100 entries, 0 to 3099
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Booking_ID     1542 non-null   str
#  1   Customer_Name  2456 non-null   str
#  2   Destination    3100 non-null   str
#  3   Service_Type   3100 non-null   str
#  4   Booking_Date   2282 non-null   str
#  5   Travel_Date    2329 non-null   str
#  6   Amount_INR     1548 non-null   float64
#  7   Rating         2555 non-null   float64
#  8   Status         3100 non-null   str
#  9   Agent_Name     3100 non-null   str
# dtypes: float64(2), str(8)
# memory usage: 242.3 KB

# %%
df.head(10)
# Out:
#   Booking_ID Customer_Name Destination  Service_Type Booking_Date Travel_Date  \
# 0       BKG1          John      Jaipur        Flight   15-02-2025  15-07-2025
# 1       BKG2         Priya         Goa        Flight   15-01-2025  15-07-2025
# 2        NaN          John       Delhi        Resort          NaN  12-08-2025
# 3       BKG4         Anita      Mumbai  Tour Package   03-10-2025  12-08-2025
# 4       BKG5           NaN      Jaipur      Homestay   03-10-2025  15-07-2025
# 5       BKG6          Amit      Mumbai           Cab   03-10-2025         NaN
# 6        NaN         Priya       Delhi        Cruise   15-02-2025  15-07-2025
# 7        NaN          John         Goa      Homestay   15-01-2025  12-08-2025
# 8        NaN          Amit   Hyderabad           Cab          NaN  15-07-2025
# 9        NaN           NaN   Bengaluru        Cruise          NaN  12-08-2025
#
#    Amount_INR  Rating     Status    Agent_Name
# 0     28868.0     5.0  confirmed   Rohit Gupta
# ...

# %%
df.tail(10)
# Out:
#      Booking_ID Customer_Name Destination  Service_Type Booking_Date  \
# 3090        NaN         Priya      Mumbai        Flight   15-02-2025
# 3091    BKG1793         Rahul     Chennai  Tour Package   03-10-2025
# 3092    BKG2030         Priya      Jaipur         Hotel          NaN
# 3093        NaN          Amit     Chennai        Cruise          NaN
# 3094        NaN        Vikram     Chennai  Tour Package   15-02-2025
# 3095    BKG2186         Rahul      Jaipur        Cruise          NaN
# 3096    BKG1673           NaN   Bengaluru        Flight   03-10-2025
# 3097        NaN        Vikram      Mumbai           Cab   03-10-2025
# 3098    BKG2213           NaN       Kochi        Cruise   15-01-2025
# 3099    BKG1966        Vikram     Chennai         Hotel   15-01-2025
#
#      Travel_Date  Amount_INR  Rating     Status    Agent_Name
# 3090  15-07-2025         NaN     NaN    Pending   Arjun Mehta
# 3091         NaN         NaN     3.0  COMPLETED  Karthik Iyer
# ...

# %%
df.isnull()
# Out:
#       Booking_ID  Customer_Name  Destination  Service_Type  Booking_Date  \
# 0          False          False        False         False         False
# 1          False          False        False         False         False
# 2           True          False        False         False          True
# 3          False          False        False         False         False
# 4          False           True        False         False         False
# ...          ...            ...          ...           ...           ...
# 3095       False          False        False         False          True
# 3096       False           True        False         False         False
# 3097        True          False        False         False         False
# 3098       False           True        False         False         False
# 3099       False          False        False         False         False
#
#       Travel_Date  Amount_INR  Rating  Status  Agent_Name
# ...

# %%
df.isnull().sum()
# Out:
# Booking_ID       1558
# Customer_Name     644
# Destination         0
# Service_Type        0
# Booking_Date      818
# Travel_Date       771
# Amount_INR       1552
# Rating            545
# Status              0
# Agent_Name          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(5888)

# %%
df.dtypes
# Out:
# Booking_ID           str
# Customer_Name        str
# Destination          str
# Service_Type         str
# Booking_Date         str
# Travel_Date          str
# Amount_INR       float64
# Rating           float64
# Status               str
# Agent_Name           str
# dtype: object

# %%
df.to_csv("cleaned_travel_dataset.csv", index=False)

# %%
df.duplicated().sum()
# Out:
# np.int64(7)

# %%
df= df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['Booking_ID', 'Customer_Name', 'Destination', 'Service_Type',
#        'Booking_Date', 'Travel_Date', 'Amount_INR', 'Rating', 'Status',
#        'Agent_Name'],
#       dtype='str')

# %%
df.shape
# Out:
# (3093, 10)
